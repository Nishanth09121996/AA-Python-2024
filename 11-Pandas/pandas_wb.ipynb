# %%
import pandas as pd

# %%
data=pd.read_csv("Data/Product.csv",sep='\t')
data
# Out:
#      ProductKey                    Product Standard Cost   Color  \
# 0           210  HL Road Frame - Black, 58       $868.63   Black
# 1           215    Sport-100 Helmet, Black        $12.03   Black
# 2           216    Sport-100 Helmet, Black        $13.88   Black
# 3           217    Sport-100 Helmet, Black        $13.09   Black
# 4           253  LL Road Frame - Black, 58        $176.2   Black
# ..          ...                        ...           ...     ...
# 392         594    Mountain-500 Silver, 48       $308.22  Silver
# 393         595    Mountain-500 Silver, 52       $308.22  Silver
# 394         601          LL Bottom Bracket        $23.97     NaN
# 395         602          ML Bottom Bracket        $44.95     NaN
# 396         603          HL Bottom Bracket        $53.94     NaN
#
#          Subcategory     Category Background Color Format Font Color Format
# 0        Road Frames   Components                 #000000           #FFFFFF
# ...

# %%
data.sort_values(by = ["Year","Global_Sales"],ascending=False)
# Out:
#         Rank                                              Name Platform  \
# 5957    5959                            Imagine: Makeup Artist       DS
# 14390  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16241  16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16438  16441                  Brothers Conflict: Precious Baby      PSV
# 221      222                                           FIFA 17      PS4
# ...      ...                                               ...      ...
# 16307  16310                                     Freaky Flyers       GC
# 16327  16330                                         Inversion       PC
# 16366  16369                       Hakuouki: Shinsengumi Kitan      PS3
# 16427  16430                                      Virtua Quest       GC
# 16493  16496                                        The Smurfs      3DS
#
#          Year         Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
grouped_data = data.groupby(['Genre','Year'], as_index=False).agg(Total=('Global_Sales', 'sum'))
grouped_data['Rank'] = grouped_data['Total'].rank(ascending=False)
grouped_data.sort_values('Rank')
# Out:
#             Genre    Year   Total   Rank
# 29         Action  2009.0  139.36    1.0
# 355        Sports  2009.0  138.52    2.0
# 28         Action  2008.0  136.39    3.0
# 352        Sports  2006.0  136.16    4.0
# 33         Action  2013.0  125.22    5.0
# ..            ...     ...     ...    ...
# 42      Adventure  1993.0    0.07  385.0
# 258  Role-Playing  2017.0    0.04  386.0
# 296    Simulation  1985.0    0.03  387.5
# 297    Simulation  1988.0    0.03  387.5
# 37         Action  2017.0    0.01  389.0
#
# [389 rows x 4 columns]

# %%
df1 = pd.DataFrame({'rollnumber' : range(6),'Name':['a','b','c','d','e','f'] })
df1
# Out:
#    rollnumber Name
# 0           0    a
# 1           1    b
# 2           2    c
# 3           3    d
# 4           4    e
# 5           5    f

# %%
import pandas as pd

# %%
df = pd.read_csv('Data\Product.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\nisha\AppData\Local\Temp\ipykernel_5540\2966780479.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('Data\Product.csv')
# C:\Users\nisha\AppData\Local\Temp\ipykernel_5540\2966780479.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('Data\Product.csv')
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = pd.read_csv('Data\Product.csv')
#
# ...
