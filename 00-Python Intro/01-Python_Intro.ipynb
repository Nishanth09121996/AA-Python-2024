# %% [markdown]
# <center><a href='https://analyticsavenue.in/'><img src='https://analyticsavenue.in/wp-content/uploads/2023/12/Edited-Logo-1-1-1-2048x2048.png' width="200" height="100"/></a></center>
# <center><em>Analytics Avenue</em></center>

# %% [markdown]
# ## **PYTHON  INTRO**

# %% [markdown]
#  1. Python is a combination of an object oriented programming language and a scripting language built on top of C developed by Guido Van Rossum in 1981.
#
#  2. It can automate the manual tasks and expanded its wings in every field
#
# 3. It has more than 1000 predefined libraries making the tasks of different domains like
# Computer science, Analytics, Statistics, AI, Biotechnology(Bio-infomartics),Commerce person even in medicine easier.
#
# 4. It is a open source and easily codable language comparing to Java, c and c++
#
# 5. Highly paid and easily learnable language and can be easily integrated with c,c++, java. MYSQL etc.

# %% [markdown]
# **What You Can do with Python?**
# 1. Automate Simple Task
# 2. Data Science And Machine Learning
# 3. Web Development

# %% [markdown]
# **Why python is a Scripting language?**

# %% [markdown]
# 1. Scripting language makes use of an interpretor.
# 2. Scripting language allows users to develop dynamic and interactive web pages with minimum effort and less programming expertise.
#
# Lets understand about a compiler and an interpretor to gain skill about scripting language

# %% [markdown]
#  **What is a Compiler**
#  1. Compiler is a software that converts a program written in high level language (Source Language) to low level language (Object/Target/Machine Language)
#  2. They usually run on Computers with same architecture.
#  3. Since they are directly converted into machine code they are faster.
#  4. They generate an intermediate code inorder to revert back the object prioe state before deformation.

# %% [markdown]
#  **What is an Interpreter**
#
#  1. Makes the code understandable to the Machine's processor without
#  converting into byte code.
#  2. It executes the instructions line by line.
#  3. They are processed during the runtime.
#  4. They do not require the intermediate object hence memory effiecient
#  Example : JavaScript | Python

# %% [markdown]
# ## **Working Of Python**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Python Execution.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ## **C++ Vs Java vs Python**
#
# | Feature                                | C++                                    | Java                                   | Python                                 |
# |----------------------------------------|----------------------------------------|----------------------------------------|----------------------------------------|
# | **Compilation Type**                   | Compiled Programming Language         | Compiled Programming Language         | Interpreted Programming Language       |
# | **Operator Overloading**               | Supports Operator Overloading         | Does not support Operator Overloading | Supports Operator Overloading         |
# | **Inheritance**                        | Supports both single and multiple inheritances | Provides partial multiple inheritance using interfaces | Supports both single and multiple inheritances |
# | **Platform Dependency**                | Platform-dependent                    | Platform-independent                   | Platform-independent                   |
# | **Threading Support**                  | Does not support threading             | Supports threading and multithreading  | Supports multithreading                |
# | **Library Support**                    | Limited library support                | Extensive library support for concepts like UI | Extensive library support for various domains, e.g., AI, data science |
# | **Variable and Function Scope**         | Variables and functions can be used outside of classes | A class is required for every line of code | Variables and functions can be declared and used outside of classes |
# | **Compilation Speed**                  | Fast compilation                       | Slower compilation compared to C++      | Slower execution due to interpretation  |
